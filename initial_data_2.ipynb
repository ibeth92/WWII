# %%
import pandas as pd
import os

file_to_load = "THOR_WWII_DATA_CLEAN.csv"
weather_data_fails = pd.read_csv('THOR_WWII_DATA_CLEAN.csv', encoding = "ISO-8859-1", low_memory=False)

# %%
print(weather_data_fails)
# Out:
#         WWII_ID  MASTER_INDEX_NUMBER     MSNDATE THEATER    NAF  \
# 0             1                  NaN   8/15/1943     MTO  12 AF
# 1          4285              20028.0   2/20/1945     PTO   5 AF
# 2             3                  NaN   8/15/1943     MTO  12 AF
# 3             4                  NaN   8/15/1943     MTO  12 AF
# 4          8167              14639.0   2/23/1945     PTO   5 AF
# ...         ...                  ...         ...     ...    ...
# 178276   135311                  NaN  12/14/1942     PTO   RAAF
# 178277    55692                  NaN   9/18/1940     MTO   SAAF
# 178278   133019                  NaN  11/17/1942     PTO   RAAF
# 178279   178741                  NaN   2/16/1945     PTO  RNZAF
# 178280   122546                  NaN   6/11/1942     PTO   RAAF
#
#        COUNTRY_FLYING_MISSION  TGT_COUNTRY_CODE         TGT_COUNTRY  \
# 0                         USA              13.0               ITALY
# ...

# %%
clean_weather_data_fails= weather_data_fails.drop(columns= "MASTER_INDEX_NUMBER")
clean_weather_data_fails2= clean_weather_data_fails.drop(columns= "THEATER")
clean_weather_data_fails3= clean_weather_data_fails2.drop(columns= "NAF")
clean_weather_data_fails4= clean_weather_data_fails3.drop(columns= "COUNTRY_FLYING_MISSION")
clean_weather_data_fails5= clean_weather_data_fails4.drop(columns= "TGT_COUNTRY_CODE")
clean_weather_data_fails6= clean_weather_data_fails5.drop(columns= "TGT_COUNTRY")
clean_weather_data_fails7= clean_weather_data_fails6.drop(columns= "TGT_LOCATION")
clean_weather_data_fails8= clean_weather_data_fails7.drop(columns= "TGT_TYPE")
clean_weather_data_fails9= clean_weather_data_fails8.drop(columns= "TGT_ID")
clean_weather_data_fails10= clean_weather_data_fails9.drop(columns= "TGT_INDUSTRY_CODE")
clean_weather_data_fails11= clean_weather_data_fails10.drop(columns= "TGT_INDUSTRY")
clean_weather_data_fails12= clean_weather_data_fails11.drop(columns= "SOURCE_LATITUDE")
clean_weather_data_fails13= clean_weather_data_fails12.drop(columns= "SOURCE_LONGITUDE")
clean_weather_data_fails14= clean_weather_data_fails13.drop(columns= "UNIT_ID")
clean_weather_data_fails15= clean_weather_data_fails14.drop(columns= "LONGITUDE")
clean_weather_data_fails16= clean_weather_data_fails15.drop(columns= "MDS")
clean_weather_data_fails17= clean_weather_data_fails16.drop(columns= "AIRCRAFT_NAME")
clean_weather_data_fails18= clean_weather_data_fails17.drop(columns= "MSN_TYPE")
clean_weather_data_fails19= clean_weather_data_fails18.drop(columns= "TGT_PRIORITY")
clean_weather_data_fails20= clean_weather_data_fails19.drop(columns= "TGT_PRIORITY_EXPLANATION")
clean_weather_data_fails21= clean_weather_data_fails20.drop(columns= "AC_ATTACKING")
clean_weather_data_fails22= clean_weather_data_fails21.drop(columns= "ALTITUDE")
clean_weather_data_fails23= clean_weather_data_fails22.drop(columns= "ALTITUDE_FEET")
clean_weather_data_fails24= clean_weather_data_fails23.drop(columns= "NUMBER_OF_HE")
clean_weather_data_fails25= clean_weather_data_fails24.drop(columns= "TYPE_OF_HE")
clean_weather_data_fails26= clean_weather_data_fails25.drop(columns= "LBS_HE")
clean_weather_data_fails27= clean_weather_data_fails26.drop(columns= "TONS_OF_HE")
clean_weather_data_fails28= clean_weather_data_fails27.drop(columns= "NUMBER_OF_IC")
clean_weather_data_fails29= clean_weather_data_fails28.drop(columns= "LBS_IC")
clean_weather_data_fails30= clean_weather_data_fails29.drop(columns= "TONS_OF_IC")
clean_weather_data_fails31= clean_weather_data_fails30.drop(columns= "LBS_IC")
clean_weather_data_fails32= clean_weather_data_fails31.drop(columns= "NUMBER_OF_FRAG")
clean_weather_data_fails33= clean_weather_data_fails32.drop(columns= "TONS_OF_IC")
clean_weather_data_fails34= clean_weather_data_fails33.drop(columns= "TYPE_OF_FRAG")
clean_weather_data_fails35= clean_weather_data_fails34.drop(columns= "LBS_FRAG")
clean_weather_data_fails36= clean_weather_data_fails35.drop(columns= "LBS_FRAG")
clean_weather_data_fails37= clean_weather_data_fails36.drop(columns= "TONS_OF_FRAG")
clean_weather_data_fails38= clean_weather_data_fails37.drop(columns= "TOTAL_LBS")
clean_weather_data_fails39= clean_weather_data_fails38.drop(columns= "TOTAL_TONS")
clean_weather_data_fails40= clean_weather_data_fails39.drop(columns= "TAKEOFF_BASE")
clean_weather_data_fails41= clean_weather_data_fails40.drop(columns= "TAKEOFF_COUNTRY")
clean_weather_data_fails42= clean_weather_data_fails41.drop(columns= "TAKEOFF_LATITUDE")
clean_weather_data_fails43= clean_weather_data_fails42.drop(columns= "TAKEOFF_LONGITUDE")
clean_weather_data_fails44= clean_weather_data_fails43.drop(columns= "AC_LOST")
clean_weather_data_fails45= clean_weather_data_fails44.drop(columns= "AC_DAMAGED")
clean_weather_data_fails46= clean_weather_data_fails45.drop(columns= "AC_AIRBORNE")
clean_weather_data_fails47= clean_weather_data_fails46.drop(columns= "AC_DROPPING")
clean_weather_data_fails48= clean_weather_data_fails47.drop(columns= "TIME_OVER_TARGET")
clean_weather_data_fails49= clean_weather_data_fails48.drop(columns= "SIGHTING_METHOD_CODE")
clean_weather_data_fails50= clean_weather_data_fails49.drop(columns= "SIGHTING_EXPLANATION")
clean_weather_data_fails51= clean_weather_data_fails50.drop(columns= "BDA")
clean_weather_data_fails52= clean_weather_data_fails51.drop(columns= "CALLSIGN")
clean_weather_data_fails53= clean_weather_data_fails52.drop(columns= "ROUNDS_AMMO")
clean_weather_data_fails54= clean_weather_data_fails53.drop(columns= "SPARES_RETURN_AC")
clean_weather_data_fails55= clean_weather_data_fails54.drop(columns= "WX_FAIL_AC")
clean_weather_data_fails56= clean_weather_data_fails55.drop(columns= "MECH_FAIL_AC")
clean_weather_data_fails57= clean_weather_data_fails56.drop(columns= "MISC_FAIL_AC")
clean_weather_data_fails58= clean_weather_data_fails57.drop(columns= "TARGET_COMMENT")
clean_weather_data_fails59= clean_weather_data_fails58.drop(columns= "MISSION_COMMENTS")
clean_weather_data_fails60= clean_weather_data_fails59.drop(columns= "SOURCE")
clean_weather_data_fails61= clean_weather_data_fails60.drop(columns= "SIGHTING_METHOD_CODE")

print(clean_weather_data_fail61)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-2a1ed39abc99> in <module>
#      29 clean_weather_data_fails29= clean_weather_data_fails28.drop(columns= "LBS_IC")
#      30 clean_weather_data_fails30= clean_weather_data_fails29.drop(columns= "TONS_OF_IC")
# ---> 31 clean_weather_data_fails31= clean_weather_data_fails30.drop(columns= "LBS_IC")
#      32 clean_weather_data_fails32= clean_weather_data_fails31.drop(columns= "NUMBER_OF_FRAG")
#      33 clean_weather_data_fails33= clean_weather_data_fails32.drop(columns= "TONS_OF_IC")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ...
